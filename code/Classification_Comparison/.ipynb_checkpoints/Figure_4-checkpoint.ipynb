# %%
from Bio.Seq import Seq
from Bio import SeqIO
import pandas as pd
test_df = pd.read_csv("Test_Data.csv")

# %%
test_df
# Out:
#        Sample  Accession Original Bank Genotyping Institution  species  \
# 0        8697       8697           OSU                    OSU      SLL
# 1        8698       8698           OSU                    OSU      SLL
# 2        8699       8699           OSU                    OSU      SLL
# 3        8700       8700           OSU                    OSU      SLL
# 4        8701       8701           OSU                    OSU      SLL
# 5        8805       8805           OSU                    OSU      SLL
# 6    071733-1   071733-1       Cornell                    OSU  mixture
# 7    071820-2   071820-2       Cornell                    OSU  mixture
# 8   091004-15  091004-15       Cornell                    OSU  mixture
# 9    091109-3   091109-3       Cornell                    OSU      SLL
# 10   091119-2   091119-2       Cornell                    OSU      SLL
# 11   091120-2   091120-2       Cornell                    OSU      SLL
# ...
